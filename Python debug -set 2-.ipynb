# %%
#1.Find the error in the following Python code:
import math
print(Math.sqrt(16))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16692\2213674736.py in <module>
#       1 #1.Find the error in the following Python code:
#       2 import math
# ----> 3 print(Math.sqrt(16))
#
# NameError: name 'Math' is not defined

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
def my_function():
    x += 5
    print(x)

x = 10
my_function()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16692\575309639.py in <module>
#       5
#       6 x = 10
# ----> 7 my_function()
#
# ~\AppData\Local\Temp\ipykernel_16692\575309639.py in my_function()
#       1 #2.Find the error in the following Python code:
#       2 def my_function():
# ----> 3     x += 5
#       4     print(x)
#       5
#
# UnboundLocalError: local variable 'x' referenced before assignment

# %%
def my_function():
    global x
    x += 5
    print(x)

x = 10
my_function()
# Out:
# 15

# %%
#3.x = 5
if x = 10:
    print("x is 10")
# Out:
#   File "C:\Users\VENKAT\AppData\Local\Temp\ipykernel_16692\2096591078.py", line 2
#     if x = 10:
#          ^
# SyntaxError: invalid syntax

# %%
x = 5
if x == 10:
    print("x is 10")

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())
# Out:
# None

# %%
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    n * n

print(square(4))
# Out:
# None

# %%
def square(n):
    return n * n

print(square(4))
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16692\4172588082.py in <module>
#       1 #6.
#       2 my_tuple = (1, 2, 3)
# ----> 3 my_tuple[1] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_tuple = (1, 5, 3)

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16692\1943582131.py in <module>
#       2 name = "Alice"
#       3 age = 25
# ----> 4 print("My name is %s and I am %d years old" % (name))
#
# TypeError: not enough arguments for format string

# %%
print("My name is %s and I am %d years old" % (name, age))
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")

# %%
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
for i in range(5, 1):
    print(i)

# %%
for i in range(5, 1, -1):  # Step should be negative to decrement
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
student = {"name": "John", "age": 20}
print(student[name])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16692\3181492965.py in <module>
#       1 #10.
#       2 student = {"name": "John", "age": 20}
# ----> 3 print(student[name])
#
# KeyError: 'Alice'

# %%
print(student["name"])
# Out:
# John
