# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# %%
 for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 a = 10
#       4 b = "5"
# ----> 5 print(a + b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Either convert the variable b to integer from string or convert the variable a to string.

a = 10
b = "5"
print(a+int(b))
# Out:
# 15

# %%
a = 10
b = "5"
print(str(a)+b)
# Out:
# 105

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
  return a + b
# Out:
#   Cell In[9], line 3
#     def add_numbers(a, b)
#     ^
# IndentationError: unexpected indent

# %%
 def add_numbers(a, b):
  return a + b

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])
# Out:
#   Cell In[11], line 3
#     numbers = [1, 2, 3, 4]
#     ^
# IndentationError: unexpected indent

# %%
numbers = [1, 2, 3, 4]
print(numbers[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 numbers = [1, 2, 3, 4]
# ----> 2 print(numbers[4])
#
# IndexError: list index out of range

# %%
#we don't have index for 4, so thats the reason its showing as list index out of range

# %%
#5.Find the error in the following Python code:
print "Hello, World!"
# Out:
#   Cell In[13], line 2
#     print "Hello, World!"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
# Missing parenthesis()

# %%
#6.Find the error in the following Python code:
x = 5 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 #6.Find the error in the following Python code:
# ----> 2 x = 5 / 0
#
# ZeroDivisionError: division by zero

# %%
# We can't divide any number by zero, results in error

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 #7.Find the error in the following Python code:name = "Alice"
#       2 age = 25
# ----> 3 print("Name: " + name + ", Age: " + age)
#
# NameError: name 'name' is not defined

# %%
#variable name is updated as comment

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
#A negative step means Python will count backwards, but since 1 is less than 10, the loop has no valid numbers to generate, so it won’t run at all.

#This does not throw a runtime error — it just produces no output.

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")
# Out:
#   Cell In[21], line 3
#     if x = 5:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
x = 10
if x == 5:
    print("x is 5")

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)
# Out:
#   Cell In[24], line 3
#     def greet(name)
#                    ^
# SyntaxError: expected ':'

# %%
def greet(name):
    print("Hello, " + name)
